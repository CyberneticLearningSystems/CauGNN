# %% [markdown]
# # Libraries

# %%
from pathlib import Path
import pickle

# %%
checkpoint_dir = '/Users/janikvollenweider/Library/CloudStorage/OneDrive-ZHAW/1Daten/40_Papers/2024-07_ATRS_AirlineProfit_wCausalAI_Conference/GitHub/CauGNN/models/ray_results/run_airline_training_2024-05-24_16-51-26/run_airline_training_18de0_00001_1_batch_size=16,channel_size=1,hid1=30,hid2=10,lr=0.0370_2024-05-24_16-51-27/checkpoint_000002/'
data_path = Path(checkpoint_dir) / "data.pkl"
with open(data_path, "rb") as fp:
    best_checkpoint_data = pickle.load(fp)
best_model_state_dict = best_checkpoint_data["net_state_dict"]

# %%
best_model_state_dict
# Out:
# OrderedDict([('conv1.weight', tensor([[[[-0.1706, -0.4609, -0.1520]]]])),
#              ('conv1.bias', tensor([-0.5519])),
#              ('conv2.weight',
#               tensor([[[[-0.5472,  0.0724,  0.2291,  0.1005, -0.0197]]]])),
#              ('conv2.bias', tensor([-0.2235])),
#              ('conv3.weight',
#               tensor([[[[-0.4098, -0.4871,  0.1214, -0.0471, -0.1990, -0.3676,  0.1072]]]])),
#              ('conv3.bias', tensor([0.1239])),
#              ('gnn1.weight',
#               tensor([[-0.2274,  0.1610, -0.2058,  0.0497,  0.2296, -0.2815,  0.1036, -0.1915,
#                        -0.0662, -0.0530, -0.1329,  0.0144,  0.1305,  0.1622,  0.1018,  0.0969,
#                        -0.1655, -0.0307, -0.1464,  0.0395,  0.1427,  0.0413, -0.0657,  0.1844,
#                         0.1773, -0.1398, -0.1734, -0.0846,  0.1202, -0.1255],
#                       [ 0.1672, -0.0948,  0.2245, -0.2568,  0.1398, -0.2345,  0.2291,  0.0138,
# ...
